# %% [markdown]
# # Tinyllama benchmark

# %% [markdown]
# In this notebook we are going to use the modularization in src/ to try the Tinyllama model quant.

# %%
import sys

sys.path.append("../src")

# %% [markdown]
# ## Import benchmark

# %%
from benchmarking import run_benchmark

# %% [markdown]
# ## Execute benchmark FP16

# %%
df_tll_fp16 = run_benchmark(
    model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    precision="fp16"
)

print(df_tll_fp16)
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# ...
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#                                 model precision  inference_time  \
# 0  TinyLlama/TinyLlama-1.1B-Chat-v1.0      fp16        8.821942
#
#    tokens_per_second  ram_usage_gb
# ...

# %% [markdown]
# ## Benchmark for INT8

# %%
df_tll_int8 = run_benchmark(
    model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    precision="int8"
)

print(df_tll_int8)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /Users/aldan/Desktop/proyectos/benchmark_quant_llm/venv/lib/python3.12/site-packages/bitsandbytes/autograd/_functions.py:123: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#                                 model precision  inference_time  \
# 0  TinyLlama/TinyLlama-1.1B-Chat-v1.0      int8        5.070876
#
#    tokens_per_second  ram_usage_gb
# 0          36.482847      0.013382

# %% [markdown]
# ## Benchmark for INT4

# %%
df_tll_int4 = run_benchmark(
    model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    precision="int4"
)

print(df_tll_int4)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# /Users/aldan/Desktop/proyectos/benchmark_quant_llm/venv/lib/python3.12/site-packages/bitsandbytes/backends/default/ops.py:223: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=2048) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /Users/aldan/Desktop/proyectos/benchmark_quant_llm/venv/lib/python3.12/site-packages/bitsandbytes/backends/cpu/ops.py:132: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#                                 model precision  inference_time  \
# ...

# %% [markdown]
# # Comparison Tinyllama

# %%
import pandas as pd

comparison = pd.concat([
    df_tll_fp16,
    df_tll_int8,
    df_tll_int4
])

print(comparison)
# Out:
#                                 model precision  inference_time  \
# 0  TinyLlama/TinyLlama-1.1B-Chat-v1.0      fp16        8.821942
# 0  TinyLlama/TinyLlama-1.1B-Chat-v1.0      int8        5.070876
# 0  TinyLlama/TinyLlama-1.1B-Chat-v1.0      int4      304.796157
#
#    tokens_per_second  ram_usage_gb
# 0          20.970439      0.560654
# 0          36.482847      0.013382
# 0           0.606963     -0.128815
